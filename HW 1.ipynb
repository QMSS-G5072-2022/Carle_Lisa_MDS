# %% [markdown]
# ## Favorite Data Science Blog & Logo
# [FiveThirtyEight](https://fivethirtyeight.com/)
# ![Screen%20Shot%202022-09-18%20at%2010.57.03%20PM.png](attachment:Screen%20Shot%202022-09-18%20at%2010.57.03%20PM.png)

# %% [markdown]
# ## Favorite Quote
# > "Thousands of candles can be lighted from a single candle, and the life of the candle will not be shortened. Happiness never decreases by being shared."
# >
# > *-Buddha*

# %%
pip install matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 25.4 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 29.2 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.4/65.4 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.2/241.2 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 959.8/959.8 kB 32.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Latex Formula and Plot
# $ y = x^{1/3} -2$

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
x = np.arange(0,1001)
y = x**(1/3) - 2
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## 5 Useful Python Packages
# Python Package | Github Stars
# :-------------:|:------------:
# NumPy | 21.5k
# Pillow | 10.2k
# Bokeh | 16.7k
# Matplotlib | 16.1k
# Pandas | 35.2k

# %% [markdown]
# ## Execute Shell Command

# %%
# !pwd
# Out:
# /Users/lisayokocarle/mds_course/Carle_Lisa

# %% [markdown]
# ## Run External Script

# %%
import nbimporter
from HW1_2 import configuration

configuration()
# Out:
# The answer is 42
